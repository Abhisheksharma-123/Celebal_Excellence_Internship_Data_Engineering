# %%
# %run ./00_setup_config
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://landing@sthealthcareamit.dfs.core.windows.net/appointments.csv</td><td>appointments.csv</td><td>10907</td><td>1783767831000</td></tr><tr><td>abfss://landing@sthealthcareamit.dfs.core.windows.net/billing.csv</td><td>billing.csv</td><td>10018</td><td>1783767831000</td></tr><tr><td>abfss://landing@sthealthcareamit.dfs.core.windows.net/doctors.csv</td><td>doctors.csv</td><td>962</td><td>1783767831000</td></tr><tr><td>abfss://landing@sthealthcareamit.dfs.core.windows.net/patients.csv</td><td>patients.csv</td><td>5626</td><td>1783767831000</td></tr><tr><td>abfss://landing@sthealthcareamit.dfs.core.windows.net/treatments.csv</td><td>treatments.csv</td><td>11072</td><td>1783767831000</td></tr></tbody></table></div>
# Batch ID : 5dc0a26d-1ab8-422e-a6a9-a39a38e352dc
# Pipeline Version : 1.0
# Run Time : 2026-07-11 12:20:15.249473
# ###Setting metadata
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_name</th><th>file_name</th><th>target_table</th><th>primary_key</th><th>load_type</th><th>active_flag</th></tr></thead><tbody><tr><td>patients</td><td>patients.csv</td><td>bronze_patients</td><td>Patient_ID</td><td>FULL</td><td>Y</td></tr><tr><td>doctors</td><td>doctors.csv</td><td>bronze_doctors</td><td>Doctor_ID</td><td>FULL</td><td>Y</td></tr><tr><td>appointments</td><td>appointments.csv</td><td>bronze_appointments</td><td>Appointment_ID</td><td>FULL</td><td>Y</td></tr><tr><td>billing</td><td>billing.csv</td><td>bronze_billing</td><td>Billing_ID</td><td>FULL</td><td>Y</td></tr><tr><td>treatments</td><td>treatments.csv</td><td>bronze_treatments</td><td>Treatment_ID</td><td>FULL</td><td>Y</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_name</th><th>file_name</th><th>target_table</th><th>primary_key</th><th>load_type</th><th>active_flag</th></tr></thead><tbody><tr><td>patients</td><td>patients.csv</td><td>bronze_patients</td><td>Patient_ID</td><td>FULL</td><td>Y</td></tr><tr><td>doctors</td><td>doctors.csv</td><td>bronze_doctors</td><td>Doctor_ID</td><td>FULL</td><td>Y</td></tr><tr><td>appointments</td><td>appointments.csv</td><td>bronze_appointments</td><td>Appointment_ID</td><td>FULL</td><td>Y</td></tr><tr><td>billing</td><td>billing.csv</td><td>bronze_billing</td><td>Billing_ID</td><td>FULL</td><td>Y</td></tr><tr><td>treatments</td><td>treatments.csv</td><td>bronze_treatments</td><td>Treatment_ID</td><td>FULL</td><td>Y</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>batch_id</th><th>source_name</th><th>layer</th><th>rows_read</th><th>rows_written</th><th>status</th><th>start_time</th><th>end_time</th><th>error_message</th></tr></thead><tbody></tbody></table></div>

# %%
from pyspark.sql import functions as F

# %%
appointments_df = (
    spark.read
    .format("delta")
    .load(f"{bronze_path}appointments")
)

display(appointments_df.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>appointment_id</th><th>patient_id</th><th>doctor_id</th><th>appointment_date</th><th>appointment_time</th><th>reason_for_visit</th><th>status</th><th>_ingestion_timestamp</th><th>_source_file_name</th><th>_batch_id</th><th>_layer</th><th>_pipeline_version</th><th>_ingestion_date</th></tr></thead><tbody><tr><td>A001</td><td>P034</td><td>D009</td><td>2023-08-09</td><td>2026-07-11T15:15:00Z</td><td>Therapy</td><td>Scheduled</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A002</td><td>P032</td><td>D004</td><td>2023-06-09</td><td>2026-07-11T14:30:00Z</td><td>Therapy</td><td>No-show</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A003</td><td>P048</td><td>D004</td><td>2023-06-28</td><td>2026-07-11T08:00:00Z</td><td>Consultation</td><td>Cancelled</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A004</td><td>P025</td><td>D006</td><td>2023-09-01</td><td>2026-07-11T09:15:00Z</td><td>Consultation</td><td>Cancelled</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A005</td><td>P040</td><td>D003</td><td>2023-07-06</td><td>2026-07-11T12:45:00Z</td><td>Emergency</td><td>No-show</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A006</td><td>P045</td><td>D006</td><td>2023-06-19</td><td>2026-07-11T16:15:00Z</td><td>Checkup</td><td>Scheduled</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A007</td><td>P001</td><td>D007</td><td>2023-04-09</td><td>2026-07-11T10:30:00Z</td><td>Consultation</td><td>Scheduled</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A008</td><td>P016</td><td>D010</td><td>2023-05-24</td><td>2026-07-11T08:45:00Z</td><td>Consultation</td><td>Cancelled</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A009</td><td>P039</td><td>D010</td><td>2023-03-05</td><td>2026-07-11T13:45:00Z</td><td>Follow-up</td><td>Scheduled</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A010</td><td>P005</td><td>D003</td><td>2023-01-13</td><td>2026-07-11T15:30:00Z</td><td>Therapy</td><td>Completed</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A011</td><td>P022</td><td>D007</td><td>2023-11-12</td><td>2026-07-11T16:00:00Z</td><td>Checkup</td><td>No-show</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A012</td><td>P029</td><td>D003</td><td>2023-05-07</td><td>2026-07-11T10:00:00Z</td><td>Follow-up</td><td>Completed</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td></tr><tr><td>A013</td><td>P003</td><td>D002</td><td>2023-08-16</td><td>2026-07-11T12:00:00Z</td><td>Emergency</td><td>Scheduled</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9 ...

# %%
patients_df = (
    spark.read
    .format("delta")
    .load(f"{silver_path}patients")
)

# %%
appointments_df.printSchema()

print("Rows :", appointments_df.count())

display(appointments_df.describe())
# Out:
# root
#  |-- appointment_id: string (nullable = true)
#  |-- patient_id: string (nullable = true)
#  |-- doctor_id: string (nullable = true)
#  |-- appointment_date: date (nullable = true)
#  |-- appointment_time: timestamp (nullable = true)
#  |-- reason_for_visit: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- _ingestion_timestamp: timestamp (nullable = true)
#  |-- _source_file_name: string (nullable = true)
#  |-- _batch_id: string (nullable = true)
#  |-- _layer: string (nullable = true)
#  |-- _pipeline_version: string (nullable = true)
#  |-- _ingestion_date: date (nullable = true)
#
# Rows : 200
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>appointment_id</th><th>patient_id</th><th>doctor_id</th><th>reason_for_visit</th><th>status</th><th>_source_file_name</th><th>_batch_id</th><th>_layer</th><th>_pipeline_version</th></tr></thead><tbody><tr><td>count</td><td>200</td><td>200</td><td>200</td><td>200</td><td>200</td><td>200</td><td>200</td><td>200</td><td>200</td></tr><tr><td>mean</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1.0</td></tr><tr><td>stddev</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.0</td></tr><tr><td>min</td><td>A001</td><td>P001</td><td>D001</td><td>Checkup</td><td>Cancelled</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td></tr><tr><td>max</td><td>A200</td><td>P050</td><td>D010</td><td>Therapy</td><td>Scheduled</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td></tr></tbody></table></div>

# %% [markdown]
# ###Remove Duplicate

# %%
appointments_df = appointments_df.dropDuplicates(["appointment_id"])

# %%
print("After removing duplicates :", appointments_df.count())
# Out:
# After removing duplicates : 200

# %% [markdown]
# ###Remove Invalid Records

# %%
appointments_df = appointments_df.na.drop(
    subset=[
        "appointment_id",
        "patient_id",
        "doctor_id"
    ]
)

# %% [markdown]
# ###Standardize Text Columns

# %%
appointments_df = (
    appointments_df
    .withColumn(
        "reason_for_visit",
        F.trim("reason_for_visit")
    )
    .withColumn(
        "status",
        F.upper(F.trim("status"))
    )
)

# %%
appointments_df = appointments_df.filter(
    F.col("appointment_date").isNotNull()
)

# %%
appointments_df = appointments_df.join(

    patients_df.select("patient_id"),

    on="patient_id",

    how="inner"

)

# %%
appointments_df = appointments_df.withColumn(
    "no_show_flag",
    F.when(
        F.col("status") == "NO SHOW",
        1
    ).otherwise(0)
)

# %%
appointments_df = appointments_df.withColumn(

    "is_weekend",

    F.when(

        F.dayofweek("appointment_date").isin([1,7]),

        1

    ).otherwise(0)

)

# %%
appointments_df = (

    appointments_df

    .withColumn(
        "_dq_passed",
        F.lit(True)
    )

    .withColumn(
        "_silver_load_timestamp",
        F.current_timestamp()
    )

    .withColumn(
        "_silver_batch_id",
        F.lit(batch_id)
    )

    .withColumn(
        "_bronze_batch_id",
        F.col("_batch_id")
    )

    .withColumn(
        "_is_current",
        F.lit(True)
    )

    .withColumn(
        "_record_version",
        F.lit(1)
    )

)

# %%
appointments_df.write \
.format("delta") \
.mode("overwrite") \
.save(f"{silver_path}appointments")

# %%
silver_appointments = (

    spark.read

    .format("delta")

    .load(f"{silver_path}appointments")

)

display(silver_appointments.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patient_id</th><th>appointment_id</th><th>doctor_id</th><th>appointment_date</th><th>appointment_time</th><th>reason_for_visit</th><th>status</th><th>_ingestion_timestamp</th><th>_source_file_name</th><th>_batch_id</th><th>_layer</th><th>_pipeline_version</th><th>_ingestion_date</th><th>no_show_flag</th><th>is_weekend</th><th>_dq_passed</th><th>_silver_load_timestamp</th><th>_silver_batch_id</th><th>_bronze_batch_id</th><th>_is_current</th><th>_record_version</th></tr></thead><tbody><tr><td>P001</td><td>A197</td><td>D005</td><td>2023-04-01</td><td>2026-07-11T13:30:00Z</td><td>Emergency</td><td>NO-SHOW</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td><td>0</td><td>1</td><td>true</td><td>2026-07-11T12:34:48.739Z</td><td>5dc0a26d-1ab8-422e-a6a9-a39a38e352dc</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>true</td><td>1</td></tr><tr><td>P034</td><td>A043</td><td>D005</td><td>2023-03-29</td><td>2026-07-11T09:15:00Z</td><td>Consultation</td><td>NO-SHOW</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td><td>0</td><td>0</td><td>true</td><td>2026-07-11T12:34:48.739Z</td><td>5dc0a26d-1ab8-422e-a6a9-a39a38e352dc</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>true</td><td>1</td></tr><tr><td>P008</td><td>A194</td><td>D002</td><td>2023-04-06</td><td>2026-07-11T12:45:00Z</td><td>Therapy</td><td>SCHEDULED</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td><td>0</td><td>0</td><td>true</td><td>2026-07-11T12:34:48.739Z</td><td>5dc0a26d-1ab8-422e-a6a9-a39a38e352dc</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>true</td><td>1</td></tr><tr><td>P016</td><td>A052</td><td>D008</td><td>2023-07-12</td><td>2026-07-11T09:30:00Z</td><td>Therapy</td><td>NO-SHOW</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td><td>0</td><td>0</td><td>true</td><td>2026-07-11T12:34:48.739Z</td><td>5dc0a26d-1ab8-422e-a6a9-a39a38e352dc</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>true</td><td>1</td></tr><tr><td>P019</td><td>A193</td><td>D005</td><td>2023-09-15</td><td>2026-07-11T08:15:00Z</td><td>Therapy</td><td>CANCELLED</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td><td>0</td><td>0</td><td>true</td><td>2026-07-11T12:34:48.739Z</td><td>5dc0a26d-1ab8-422e-a6a9-a39a38e352dc</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>true</td><td>1</td></tr><tr><td>P037</td><td>A017</td><td>D009</td><td>2023-07-11</td><td>2026-07-11T17:00:00Z</td><td>Emergency</td><td>SCHEDULED</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td><td>0</td><td>0</td><td>true</td><td>2026-07-11T12:34:48.739Z</td><td>5dc0a26d-1ab8-422e-a6a9-a39a38e352dc</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>true</td><td>1</td></tr><tr><td>P012</td><td>A174</td><td>D002</td><td>2023-10-31</td><td>2026-07-11T11:15:00Z</td><td>Follow-up</td><td>CANCELLED</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.csv</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>BRONZE</td><td>1.0</td><td>2026-07-11</td><td>0</td><td>0</td><td>true</td><td>2026-07-11T12:34:48.739Z</td><td>5dc0a26d-1ab8-422e-a6a9-a39a38e352dc</td><td>dd177b19-f197-444a-9d50-bcf4524563e3</td><td>true</td><td>1</td></tr><tr><td>P016</td><td>A008</td><td>D010</td><td>2023-05-24</td><td>2026-07-11T08:45:00Z</td><td>Consultation</td><td>CANCELLED</td><td>2026-07-11T11:51:42.351Z</td><td>appointments.cs ...
