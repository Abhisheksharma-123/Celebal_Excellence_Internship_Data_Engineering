# %%
# %run 
"./00setup_config"
# Out:
# Connected. Database ready.
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://landing@medallionhealthdata03.dfs.core.windows.net/appointments.csv</td><td>appointments.csv</td><td>10907</td><td>1783938174000</td></tr><tr><td>abfss://landing@medallionhealthdata03.dfs.core.windows.net/billing.csv</td><td>billing.csv</td><td>10018</td><td>1783938174000</td></tr><tr><td>abfss://landing@medallionhealthdata03.dfs.core.windows.net/doctors.csv</td><td>doctors.csv</td><td>962</td><td>1783938174000</td></tr><tr><td>abfss://landing@medallionhealthdata03.dfs.core.windows.net/patients.csv</td><td>patients.csv</td><td>5626</td><td>1783938174000</td></tr><tr><td>abfss://landing@medallionhealthdata03.dfs.core.windows.net/treatments.csv</td><td>treatments.csv</td><td>11072</td><td>1783938174000</td></tr></tbody></table></div>
# Batch ID : 1bed4ce8-4b1d-459a-88db-1c1c76ecfa44
# Pipeline Version : 1.0
# Run Time : 2026-07-13 10:53:07.007017
# # Setting metadata
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_name</th><th>file_name</th><th>target_table</th><th>primary_key</th><th>load_type</th><th>active_flag</th></tr></thead><tbody><tr><td>patients</td><td>patients.csv</td><td>bronze_patients</td><td>Patient_ID</td><td>FULL</td><td>Y</td></tr><tr><td>doctors</td><td>doctors.csv</td><td>bronze_doctors</td><td>Doctor_ID</td><td>FULL</td><td>Y</td></tr><tr><td>appointments</td><td>appointments.csv</td><td>bronze_appointments</td><td>Appointment_ID</td><td>FULL</td><td>Y</td></tr><tr><td>billing</td><td>billing.csv</td><td>bronze_billing</td><td>Billing_ID</td><td>FULL</td><td>Y</td></tr><tr><td>treatments</td><td>treatments.csv</td><td>bronze_treatments</td><td>Treatment_ID</td><td>FULL</td><td>Y</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>source_name</th><th>file_name</th><th>target_table</th><th>primary_key</th><th>load_type</th><th>active_flag</th></tr></thead><tbody><tr><td>patients</td><td>patients.csv</td><td>bronze_patients</td><td>Patient_ID</td><td>FULL</td><td>Y</td></tr><tr><td>doctors</td><td>doctors.csv</td><td>bronze_doctors</td><td>Doctor_ID</td><td>FULL</td><td>Y</td></tr><tr><td>appointments</td><td>appointments.csv</td><td>bronze_appointments</td><td>Appointment_ID</td><td>FULL</td><td>Y</td></tr><tr><td>billing</td><td>billing.csv</td><td>bronze_billing</td><td>Billing_ID</td><td>FULL</td><td>Y</td></tr><tr><td>treatments</td><td>treatments.csv</td><td>bronze_treatments</td><td>Treatment_ID</td><td>FULL</td><td>Y</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>batch_id</th><th>source_name</th><th>layer</th><th>rows_read</th><th>rows_written</th><th>status</th><th>start_time</th><th>end_time</th><th>error_message</th></tr></thead><tbody></tbody></table></div>

# %%
from pyspark.sql import functions as F

# %%
patients_df = (
    spark.read
    .format("delta")
    .load(f"{bronze_path}patients")
)

display(patients_df.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
td><td>INS545101</td><td>david.davis@mail.com</td><td>2026-07-13T10:52:36.822824Z</td><td>patients.csv</td><td>3f6a3ded-77bf-47b4-adb2-e511534929d7</td><td>BRONZE</td><td>1.0</td><td>2026-07-13</td></tr><tr><td>P009</td><td>Laura</td><td>Davis</td><td>M</td><td>1971-12-11</td><td>7060324619</td><td>321 Maple Dr</td><td>2022-09-18</td><td>PulseSecure</td><td>INS136631</td><td>laura.davis@mail.com</td><td>2026-07-13T10:52:36.822824Z</td><td>patients.csv</td><td>3f6a3ded-77bf-47b4-adb2-e511534929d7</td><td>BRONZE</td><td>1.0</td><td>2026-07-13</td></tr><tr><td>P010</td><td>Michael</td><td>Taylor</td><td>M</td><td>2001-10-13</td><td>7081396733</td><td>123 Elm St</td><td>2022-08-24</td><td>WellnessCorp</td><td>INS866577</td><td>michael.taylor@mail.com</td><td>2026-07-13T10:52:36.822824Z</td><td>patients.csv</td><td>3f6a3ded-77bf-47b4-adb2-e511534929d7</td><td> ...

# %%
patients_df.printSchema()
# Out:
# root
#  |-- patient_id: string (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- date_of_birth: date (nullable = true)
#  |-- contact_number: long (nullable = true)
#  |-- address: string (nullable = true)
#  |-- registration_date: date (nullable = true)
#  |-- insurance_provider: string (nullable = true)
#  |-- insurance_number: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- _ingestion_timestamp: timestamp (nullable = true)
#  |-- _source_file_name: string (nullable = true)
#  |-- _batch_id: string (nullable = true)
#  |-- _layer: string (nullable = true)
#  |-- _pipeline_version: string (nullable = true)
#  |-- _ingestion_date: date (nullable = true)

# %%
print("Total Records :", patients_df.count())
# Out:
# Total Records : 50

# %%
display(patients_df.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>patient_id</th><th>first_name</th><th>last_name</th><th>gender</th><th>contact_number</th><th>address</th><th>insurance_provider</th><th>insurance_number</th><th>email</th><th>_source_file_name</th><th>_batch_id</th><th>_layer</th><th>_pipeline_version</th></tr></thead><tbody><tr><td>count</td><td>50</td><td>50</td><td>50</td><td>50</td><td>50</td><td>50</td><td>50</td><td>50</td><td>50</td><td>50</td><td>50</td><td>50</td><td>50</td></tr><tr><td>mean</td><td>null</td><td>null</td><td>null</td><td>null</td><td>7.81728331796E9</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1.0</td></tr><tr><td>stddev</td><td>null</td><td>null</td><td>null</td><td>null</td><td>9.573593644707395E8</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0.0</td></tr><tr><td>min</td><td>P001</td><td>Alex</td><td>Brown</td><td>F</td><td>6141951830</td><td>123 Elm St</td><td>HealthIndia</td><td>INS104014</td><td>alex.johnson@mail.com</td><td>patients.csv</td><td>3f6a3ded-77bf-47b4-adb2-e511534929d7</td><td>BRONZE</td><td>1.0</td></tr><tr><td>max</td><td>P050</td><td>Sarah</td><td>Wilson</td><td>M</td><td>9900972256</td><td>789 Pine Rd</td><td>WellnessCorp</td><td>INS997059</td><td>sarah.miller@mail.com</td><td>patients.csv</td><td>3f6a3ded-77bf-47b4-adb2-e511534929d7</td><td>BRONZE</td><td>1.0</td></tr></tbody></table></div>

# %% [markdown]
# # Remove duplicates

# %%
patients_df = patients_df.dropDuplicates(["Patient_ID"])

# %%
print("After removing duplicates :", patients_df.count())
# Out:
# After removing duplicates : 50

# %% [markdown]
# # Handle Null Values

# %%
from pyspark.sql.functions import col, when, count

display(
    patients_df.select([
        count(when(col(c).isNull(), c)).alias(c)
        for c in patients_df.columns
    ])
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>patient_id</th><th>first_name</th><th>last_name</th><th>gender</th><th>date_of_birth</th><th>contact_number</th><th>address</th><th>registration_date</th><th>insurance_provider</th><th>insurance_number</th><th>email</th><th>_ingestion_timestamp</th><th>_source_file_name</th><th>_batch_id</th><th>_layer</th><th>_pipeline_version</th><th>_ingestion_date</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import trim

patients_df = (
    patients_df
    .withColumn("Patient_ID", trim("Patient_ID"))
    .withColumn("First_Name", trim("First_Name"))
    .withColumn("Last_Name", trim("Last_Name"))
    .withColumn("Gender", trim("Gender"))
    
)

# %%
patients_df = patients_df.withColumn(
    "Gender",
    F.upper("Gender")
)

# %% [markdown]
# # Business Validations

# %%
patients_df = (
    patients_df
    .withColumn("_dq_passed", F.lit(True))
    .withColumn("_silver_load_timestamp", F.current_timestamp())
    .withColumn("_silver_batch_id", F.lit(batch_id))
    .withColumn("_bronze_batch_id", F.col("_batch_id"))
    .withColumn("_is_current", F.lit(True))
    .withColumn("_record_version", F.lit(1))
)

# %%
patients_df.write \
    .format("delta") \
    .mode("overwrite") \
    .save(f"{silver_path}patients")

# %%
silver_patients = (
    spark.read
    .format("delta")
    .load(f"{silver_path}patients")
)

display(silver_patients.limit(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Patient_ID</th><th>First_Name</th><th>Last_Name</th><th>Gender</th><th>date_of_birth</th><th>contact_number</th><th>address</th><th>registration_date</th><th>insurance_provider</th><th>insurance_number</th><th>email</th><th>_ingestion_timestamp</th><th>_source_file_name</th><th>_batch_id</th><th>_layer</th><th>_pipeline_version</th><th>_ingestion_date</th><th>_dq_passed</th><th>_silver_load_timestamp</th><th>_silver_batch_id</th><th>_bronze_batch_id</th><th>_is_current</th><th>_record_version</th></tr></thead><tbody><tr><td>P032</td><td>Alex</td><td>Moore</td><td>M</td><td>1981-01-08</td><td>8102183595</td><td>123 Elm St</td><td>2021-10-02</td><td>MedCare Plus</td><td>INS335362</td><td>alex.moore@mail.com</td><td>2026-07-13T10:52:36.822824Z</td><td>patients.csv</td><td>3f6a3ded-77bf-47b4-adb2-e511534929d7</td><td>BRONZE</td><td>1.0</td><td>2026-07-13</td><td>true</td><td>2026-07-13T10:53:47.046929Z</td><td>1bed4ce8-4b1d-459a-88db-1c1c76ecfa44</td><td>3f6a3ded-77bf-47b4-adb2-e511534929d7</td><td>true</td><td>1</td></tr><tr><td>P012</td><td>Laura</td><td>Davis</td><td>F</td><td>1991-12-08</td><td>8135666049</td><td>321 Maple Dr</td><td>2023-04-27</td><td>MedCare Plus</td><td>INS104014</td><td>laura.davis@mail.com</td><td>2026-07-13T10:52:36.822824Z</td><td>patients.csv</td><td>3f6a3ded-77bf-47b4-ad